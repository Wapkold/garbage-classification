# %% [markdown]
# # EDA: разведочный анализ датасета
#
# ## План
# 1. Загрузка данных из `data/raw/`
# 2. Баланс классов: сколько изображений в каждом классе
# 3. Размеры и соотношения сторон изображений, цветовые режимы
# 4. Примеры изображений по каждому классу
# 5. Проблемные случаи: битые файлы, дубликаты, выбросы
# 6. Выводы: какие трансформы и аугментации нужны

# %%
# Импорты и пути к данным
